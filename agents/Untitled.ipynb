# %%
import numpy as np

# %%
mem_radius = 9

rad = int(mem_radius / 2)

a = np.arange(mem_radius) - rad
a[:rad], a[-rad:] = np.flip(a[:rad]), np.flip(a[-rad:])
kx, ky, kz = np.meshgrid(a, a, a)

# %%
a
# Out:
# array([-1, -2, -3, -4,  0,  4,  3,  2,  1])

# %%
kz
# Out:
# array([[[-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1]],
#
#        [[-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1]],
#
#        [[-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1]],
#
#        [[-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1]],
#
#        [[-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1]],
#
#        [[-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1]],
#
#        [[-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1]],
#
#        [[-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1]],
#
#        [[-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1],
#         [-1, -2, -3, -4,  0,  4,  3,  2,  1]]])
